# %%
import plotly.express as px
import numpy as np

# %%
x=[0, 1, 2, 3, 4]
y=[0, 1, 4, 9, 16]

# %%
px.scatter(x=[0, 1, 2, 3, 4],y=[0, 1, 4, 9, 16])

# %%
df = px.data.iris()

# %%
df

# %%
fig = px.scatter(df,x="sepal_width", y="sepal_length",
                 color="species",size='petal_length',
                 hover_data=['petal_width'])

# %%
fig.show()

# %%
t = np.linspace(0, 2*np.pi, 100)

# %%
px.line(x=t,y=np.cos(t),labels={'x':'t','y':'cos(t)'},)

# %%
df = px.data.gapminder().query("continent == 'Oceania'")

# %%
fig = px.line(df, x='year', y='lifeExp',color='country')
fig.show()

# %%
import plotly.express as px

# %%
import pandas as pd
#pd.set_option('display.max_rows', 100)

# %%
df = px.data.gapminder()

# %%
df[:100]
# Out:
#         country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 0   Afghanistan      Asia  1952   28.801   8425333    779.445314       AFG
# 1   Afghanistan      Asia  1957   30.332   9240934    820.853030       AFG
# 2   Afghanistan      Asia  1962   31.997  10267083    853.100710       AFG
# 3   Afghanistan      Asia  1967   34.020  11537966    836.197138       AFG
# 4   Afghanistan      Asia  1972   36.088  13079460    739.981106       AFG
# 5   Afghanistan      Asia  1977   38.438  14880372    786.113360       AFG
# 6   Afghanistan      Asia  1982   39.854  12881816    978.011439       AFG
# 7   Afghanistan      Asia  1987   40.822  13867957    852.395945       AFG
# 8   Afghanistan      Asia  1992   41.674  16317921    649.341395       AFG
# 9   Afghanistan      Asia  1997   41.763  22227415    635.341351       AFG
# 10  Afghanistan      Asia  2002   42.129  25268405    726.734055       AFG
# ...

# %%
px.area(data_frame=df, x='year', y='pop',color="continent",
        line_group="country")
# Out:
# <div>
#
#
#             <div id="73ed9baa-8a97-47d8-931d-a4bbb5edd5f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("73ed9baa-8a97-47d8-931d-a4bbb5edd5f9")) {
#                     Plotly.newPlot(
#                         '73ed9baa-8a97-47d8-931d-a4bbb5edd5f9',
# ...

# %%
dftemp = df[(df['country'] == 'Canada') | (df['country'] == 'Mexico')]

# %%
px.bar(dftemp, x='year',y='pop',
       hover_data=['lifeExp', 'gdpPercap'],
       labels={'pop':'population of Canada'},
       barmode='group',color='country',
       facet_row="country", facet_col="iso_alpha")
# Out:
# <div>
#
#
#             <div id="e32fec9f-a6c3-4c61-82a1-797313619311" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e32fec9f-a6c3-4c61-82a1-797313619311")) {
#                     Plotly.newPlot(
#                         'e32fec9f-a6c3-4c61-82a1-797313619311',
# ...

# %%
data = dict(
    number=[39, 27.4, 20.6, 11, 2],
    stage=["Website visit", "Downloads", 
           "Potential customers", "Requested price", 
           "invoice sent"])

# %%
data['stage']
# Out:
# ['Website visit',
#  'Downloads',
#  'Potential customers',
#  'Requested price',
#  'invoice sent']

# %%
data.items()
# Out:
# dict_items([('number', [39, 27.4, 20.6, 11, 2]), ('stage', ['Website visit', 'Downloads', 'Potential customers', 'Requested price', 'invoice sent'])])

# %%
px.funnel(data,x='number', y='stage')
# Out:
# <div>
#
#
#             <div id="11bed938-6ff8-45c0-8b34-3a3724773d86" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11bed938-6ff8-45c0-8b34-3a3724773d86")) {
#                     Plotly.newPlot(
#                         '11bed938-6ff8-45c0-8b34-3a3724773d86',
#                         [{"hovertemplate": "number=%{x}<br>stage=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "orientation": "h", "showlegend": false, "type": "funnel", "x": [39.0, 27.4, 20.6, 11.0, 2.0], "xaxis": "x", "y": ["Website visit", "Downloads", "Potential customers", "Requested price", "invoice sent"], "yaxis": "y"}],
# ...

# %%
import plotly.express as px
import pandas as pd

# %%
df_mtl = pd.DataFrame(data)

# %%
df_mtl['office'] = 'Montreal'

# %%
df_mtl
# Out:
#    number                stage    office
# 0    39.0        Website visit  Montreal
# 1    27.4            Downloads  Montreal
# 2    20.6  Potential customers  Montreal
# 3    11.0      Requested price  Montreal
# 4     2.0         invoice sent  Montreal

# %%
df_toronto = pd.DataFrame(
    dict(number=[52, 36, 18, 14, 5], 
         stage=stages))

df_toronto['office'] = 'Toronto'
df_toronto
# Out:
#    number                stage   office
# 0      52        Website visit  Toronto
# 1      36            Downloads  Toronto
# 2      18  Potential customers  Toronto
# 3      14      Requested price  Toronto
# 4       5         invoice sent  Toronto

# %%
df = pd.concat([df_mtl, df_toronto], axis=0)

# %%
px.funnel(df,x='number',y='stage',color='office')
# Out:
# <div>
#
#
#             <div id="f2dea7ec-0710-46bd-a56c-10aa4bc52090" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f2dea7ec-0710-46bd-a56c-10aa4bc52090")) {
#                     Plotly.newPlot(
#                         'f2dea7ec-0710-46bd-a56c-10aa4bc52090',
# ...

# %%
df = px.data.gapminder(
).query("year == 2007").query(
    "continent == 'Americas'")

# %%
px.pie(df, values='pop', names='country', 
       title='Population of American continent')
# Out:
# <div>
#
#
#             <div id="d891ab7a-ae08-413d-8403-a857b8ac0f03" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d891ab7a-ae08-413d-8403-a857b8ac0f03")) {
#                     Plotly.newPlot(
#                         'd891ab7a-ae08-413d-8403-a857b8ac0f03',
# ...

# %%
df = px.data.tips()
df = px.data.gapminder().query("year == 2007").query("continent == 'Americas'")
fig = px.pie(df, values='pop', names='country',
             title='Population of American continent',
             hover_data=['lifeExp'], labels={'lifeExp':'life expectancy'})
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>
#
#
#             <div id="02d1d140-4549-4066-99ce-39ccd0168e76" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02d1d140-4549-4066-99ce-39ccd0168e76")) {
#                     Plotly.newPlot(
#                         '02d1d140-4549-4066-99ce-39ccd0168e76',
# ...

# %%
data = dict(
    character=["Eve", "Cain", "Seth", "Enos", "Noam", "Abel", "Awan", "Enoch", "Azura"],
    parent=["", "Eve", "Eve", "Seth", "Seth", "Eve", "Eve", "Awan", "Eve" ],
    value=[10, 14, 12, 10, 2, 6, 6, 4, 4])

# %%
pd.DataFrame(data)
# Out:
#   character parent  value
# 0       Eve            10
# 1      Cain    Eve     14
# 2      Seth    Eve     12
# 3      Enos   Seth     10
# 4      Noam   Seth      2
# 5      Abel    Eve      6
# 6      Awan    Eve      6
# 7     Enoch   Awan      4
# 8     Azura    Eve      4

# %%
fig =px.sunburst(
    data,
    names='character',
    parents='parent',
    values='value',
)

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="5d46a6d7-40c4-462f-8cf8-2fc46caeebf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d46a6d7-40c4-462f-8cf8-2fc46caeebf9")) {
#                     Plotly.newPlot(
#                         '5d46a6d7-40c4-462f-8cf8-2fc46caeebf9',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "character=%{label}<br>value=%{value}<br>parent=%{parent}<extra></extra>", "labels": ["Eve", "Cain", "Seth", "Enos", "Noam", "Abel", "Awan", "Enoch", "Azura"], "name": "", "parents": ["", "Eve", "Eve", "Seth", "Seth", "Eve", "Eve", "Awan", "Eve"], "type": "sunburst", "values": [10, 14, 12, 10, 2, 6, 6, 4, 4]}],
# ...

# %%
df = px.data.tips()
fig = px.sunburst(df, path=['time', 'day', 'sex'], 
                  values='total_bill')
fig.show()
# Out:
# <div>
#
#
#             <div id="374d1bd1-5f2e-461f-8fb5-88ba5d03af79" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("374d1bd1-5f2e-461f-8fb5-88ba5d03af79")) {
#                     Plotly.newPlot(
#                         '374d1bd1-5f2e-461f-8fb5-88ba5d03af79',
# ...

# %%
import numpy as np

df = px.data.gapminder().query("year == 2007")


fig = px.sunburst(df, path=['continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))

# %%
np.average(df['lifeExp'], weights=df['pop'])
# Out:
# 68.91909251904043

# %%
px.colors.sequential.Cividis
# Out:
# ['#00224e',
#  '#123570',
#  '#3b496c',
#  '#575d6d',
#  '#707173',
#  '#8a8678',
#  '#a59c74',
#  '#c3b369',
#  '#e1cc55',
#  '#fee838']

# %%
vendors = ["A", "B", "C", "D", None, "E", "F", "G", "H", None]
sectors = ["Tech", "Tech", "Finance", "Finance", "Other",
           "Tech", "Tech", "Finance", "Finance", "Other"]
regions = ["North", "North", "North", "North", "North",
           "South", "South", "South", "South", "South"]
sales = [1, 3, 2, 4, 1, 2, 2, 1, 4, 1]
df = pd.DataFrame(
    dict(vendors=vendors, sectors=sectors, regions=regions, sales=sales)
)

# %%
df
# Out:
#   vendors  sectors regions  sales
# 0       A     Tech   North      1
# 1       B     Tech   North      3
# 2       C  Finance   North      2
# 3       D  Finance   North      4
# 4    None    Other   North      1
# 5       E     Tech   South      2
# 6       F     Tech   South      2
# 7       G  Finance   South      1
# 8       H  Finance   South      4
# 9    None    Other   South      1

# %%
fig = px.treemap(
    names = ["Eve","Cain", "Seth", "Enos", "Noam", "Abel", "Awan", "Enoch", "Azura"],
    parents = ["", "Eve", "Eve", "Seth", "Seth", "Eve", "Eve", "Awan", "Eve"]
)

# %%
fig
# Out:
# <div>
#
#
#             <div id="165542be-77f9-4687-b28e-94e23d9250b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("165542be-77f9-4687-b28e-94e23d9250b2")) {
#                     Plotly.newPlot(
#                         '165542be-77f9-4687-b28e-94e23d9250b2',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>parent=%{parent}<extra></extra>", "labels": ["Eve", "Cain", "Seth", "Enos", "Noam", "Abel", "Awan", "Enoch", "Azura"], "name": "", "parents": ["", "Eve", "Eve", "Seth", "Seth", "Eve", "Eve", "Awan", "Eve"], "type": "treemap"}],
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import plotly.express as px
df = px.data.tips()
fig = px.treemap(df, 
                 path=['day', 'time', 'sex'], 
                 values='total_bill')
fig.show()
# Out:
# <div>
#
#
#             <div id="43344d5d-0d41-49cf-9742-4da9d4003e63" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43344d5d-0d41-49cf-9742-4da9d4003e63")) {
#                     Plotly.newPlot(
#                         '43344d5d-0d41-49cf-9742-4da9d4003e63',
# ...

# %%
df = px.data.gapminder().query("year == 2007")
df["world"] = "world" # in order to have a single root node
fig = px.treemap(df, path=['world', 'continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.show()
# Out:
# <div>
#
#
#             <div id="e827f1ed-d450-44cc-991e-d96b0a560bfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e827f1ed-d450-44cc-991e-d96b0a560bfd")) {
#                     Plotly.newPlot(
#                         'e827f1ed-d450-44cc-991e-d96b0a560bfd',
# ...

# %%
import plotly.express as px
df = px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.histogram(df,x='total_bill',nbins=200)
# Out:
# <div>
#
#
#             <div id="11dc4b8e-0a35-4763-b9f8-f89b2d71b17a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("11dc4b8e-0a35-4763-b9f8-f89b2d71b17a")) {
#                     Plotly.newPlot(
#                         '11dc4b8e-0a35-4763-b9f8-f89b2d71b17a',
# ...

# %%
f = px.data.tips()
# create the bins
counts, bins = np.histogram(df.total_bill, bins=range(0, 60, 5))
bins = 0.5 * (bins[:-1] + bins[1:])

fig = px.bar(x=bins, y=counts, labels={'x':'total_bill', 'y':'count'})
fig.show()
# Out:
# <div>
#
#
#             <div id="99259a20-3b91-4bd7-ac9e-da2c40923043" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("99259a20-3b91-4bd7-ac9e-da2c40923043")) {
#                     Plotly.newPlot(
#                         '99259a20-3b91-4bd7-ac9e-da2c40923043',
#                         [{"alignmentgroup": "True", "hovertemplate": "total_bill=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5], "xaxis": "x", "y": [1, 16, 63, 67, 41, 24, 16, 6, 5, 4, 1], "yaxis": "y"}],
# ...

# %%
counts
# Out:
# array([ 1, 16, 63, 67, 41, 24, 16,  6,  5,  4,  1], dtype=int64)

# %%
df = px.data.tips()
fig = px.histogram(df, x="total_bill", color="sex", 
                   marginal="violin", # can be `box`, `violin`
                   hover_data=df.columns)

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="6d62a15e-bf2c-44ca-a63e-aa9ffeaacc50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d62a15e-bf2c-44ca-a63e-aa9ffeaacc50")) {
#                     Plotly.newPlot(
#                         '6d62a15e-bf2c-44ca-a63e-aa9ffeaacc50',
# ...

# %%
import plotly.express as px
df = px.data.tips()

fig = px.density_heatmap(df, x="total_bill", y="tip",
                         nbinsx=200,nbinsy=200,
                         facet_row="sex", 
                         facet_col="smoker",histfunc="max")
fig.show()
# Out:
# <div>
#
#
#             <div id="a7e4dbee-4e63-46d3-a042-a212f12b424e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7e4dbee-4e63-46d3-a042-a212f12b424e")) {
#                     Plotly.newPlot(
#                         'a7e4dbee-4e63-46d3-a042-a212f12b424e',
# ...

# %%
fig = px.density_heatmap(df, x="petal_length", 
                         y="petal_width", 
                         z="sepal_length",histfunc="count")
fig.show()
# Out:
# <div>
#
#
#             <div id="c14bfa64-5092-4a31-aceb-f71decb4fca4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c14bfa64-5092-4a31-aceb-f71decb4fca4")) {
#                     Plotly.newPlot(
#                         'c14bfa64-5092-4a31-aceb-f71decb4fca4',
# ...

# %%
df = px.data.tips()
fig = px.density_contour(df, x="total_bill", y="tip",)

# %%
fig.update_traces(contours_coloring="fill", contours_showlabels = True)
# Out:
# <div>
#
#
#             <div id="be54455d-b459-402b-a26f-4085263a5ae6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be54455d-b459-402b-a26f-4085263a5ae6")) {
#                     Plotly.newPlot(
#                         'be54455d-b459-402b-a26f-4085263a5ae6',
# ...

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="ff762d6b-72b7-45d7-b19b-48c08c9421d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff762d6b-72b7-45d7-b19b-48c08c9421d8")) {
#                     Plotly.newPlot(
#                         'ff762d6b-72b7-45d7-b19b-48c08c9421d8',
# ...

# %%
import plotly.graph_objects as go

import numpy as np

t = np.linspace(-1, 1.2, 2000)
x = (t**3) + (0.3 * np.random.randn(2000))
y = (t**6) + (0.3 * np.random.randn(2000))

fig = go.Figure()
fig.add_trace(go.Histogram2dContour(
        x = x,
        y = y,
        colorscale = 'Blues',
        reversescale = True,
        xaxis = 'x',
        yaxis = 'y'
    ))
fig.add_trace(go.Scatter(
        x = x,
        y = y,
        xaxis = 'x',
        yaxis = 'y',
        mode = 'markers',
        marker = dict(
            color = 'rgba(0,0,0,0.3)',
            size = 3
        )
    ))
fig.add_trace(go.Histogram(
        y = y,
        xaxis = 'x2',
        marker = dict(
            color = 'rgba(0,0,0,1)'
        )
    ))
fig.add_trace(go.Histogram(
        x = x,
        yaxis = 'y2',
        marker = dict(
            color = 'rgba(0,0,0,1)'
        )
    ))

fig.update_layout(
    autosize = False,
    xaxis = dict(
        zeroline = False,
        domain = [0,0.85],
        showgrid = False
    ),
    yaxis = dict(
        zeroline = False,
        domain = [0,0.85],
        showgrid = False
    ),
    xaxis2 = dict(
        zeroline = False,
        domain = [0.85,1],
        showgrid = False
    ),
    yaxis2 = dict(
        zeroline = False,
        domain = [0.85,1],
        showgrid = False
    ),
    height = 600,
    width = 600,
    bargap = 0,
    hovermode = 'closest',
    showlegend = False
)

fig.show()
# Out:
# <div>
#
#
#             <div id="c039c45e-1df6-4ba9-bbbc-7769ca39c7b5" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c039c45e-1df6-4ba9-bbbc-7769ca39c7b5")) {
#                     Plotly.newPlot(
#                         'c039c45e-1df6-4ba9-bbbc-7769ca39c7b5',
# ...
